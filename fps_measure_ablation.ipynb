# %%
from lib.utils.learning import load_backbone
from lib.utils.tools import get_config
import os
import subprocess
from lib.model.model_action import ActionNet

def getActionNet(yaml):
    args = get_config(yaml)
    model_backbone = load_backbone(args)
    # if args.finetune:
    #     chk_filename = os.path.join(opts.pretrained, opts.selection)
    #     print('Loading backbone', chk_filename)
    #     checkpoint = torch.load(chk_filename, map_location=lambda storage, loc: storage)['model_pos']
    #     model_backbone = load_pretrained_weights(model_backbone, checkpoint)
    # if args.partial_train:
    #     model_backbone = partial_train_layers(model_backbone, args.partial_train)
    return   ActionNet(backbone=model_backbone, dim_rep=args.dim_rep, num_classes=args.action_classes, dropout_ratio=args.dropout_ratio, version=args.model_version, hidden_dim=args.hidden_dim, num_joints=args.num_joints)


def get_gpu_memory_usage():
    """Returns GPU memory usage in GB (first device only)."""
    result = subprocess.check_output(
        ['nvidia-smi', '--query-gpu=memory.used', '--format=csv,nounits,noheader']
    )
    memory_used = int(result.decode().split('\n')[0])
    return memory_used / 1024  # Convert MB to GB

# %%
import torch
import time
import cv2
import numpy as np
from ultralytics import YOLO

# Load model (adjust path if needed)
model = YOLO("yolo11n-pose.pt")
model.eval()

# Load dummy image (or use webcam frame)
img = np.random.randint(0, 255, (640, 640, 3), dtype=np.uint8)
img_tensor = torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0).float() / 255.0  # Shape: [1, 3, 640, 640]

model_action = getActionNet('./configs/action/MB_ft_NTU60_xsub_lite_temp_comp.yaml').cuda()
model_action.eval()

input_tensor = torch.randn(1, 2, 243, 17, 3).cuda()
# Warm-up
with torch.no_grad():
    for _ in range(10):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)

# Measure FPS
num_iters = 100
torch.cuda.synchronize()
start_time = time.time()

with torch.no_grad():
    for _ in range(num_iters):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)
        torch.cuda.synchronize()

end_time = time.time()
elapsed = end_time - start_time
fps = num_iters / elapsed

print(f"YOLOv11 Pose Estimator FPS: {fps:.2f}")
# Out:
# True
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.9ms
# Speed: 3.0ms preprocess, 14.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.0ms
# Speed: 2.9ms preprocess, 17.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.7ms
# Speed: 6.1ms preprocess, 15.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.4ms
# Speed: 3.2ms preprocess, 14.4ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.5ms
# Speed: 3.0ms preprocess, 14.5ms inference, 11.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.2ms
# Speed: 2.9ms preprocess, 16.2ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.6ms
# Speed: 3.2ms preprocess, 14.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.7ms
# Speed: 2.0ms preprocess, 18.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.2ms
# Speed: 2.2ms preprocess, 13.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.6ms
# Speed: 12.8ms preprocess, 21.6ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.6ms
# Speed: 2.6ms preprocess, 20.6ms inference, 6.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.1ms
# Speed: 2.5ms preprocess, 14.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.1ms
# Speed: 3.6ms preprocess, 21.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.2ms
# Speed: 2.2ms preprocess, 17.2ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.4ms
# Speed: 3.2ms preprocess, 21.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.8ms
# Speed: 2.2ms preprocess, 18.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.1ms
# Speed: 2.2ms preprocess, 12.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.8ms
# Speed: 2.4ms preprocess, 11.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.9ms
# Speed: 1.9ms preprocess, 10.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.7ms
# Speed: 2.4ms preprocess, 27.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.7ms
# Speed: 2.0ms preprocess, 14.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.8ms
# Speed: 2.2ms preprocess, 20.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.9ms
# Speed: 2.1ms preprocess, 19.9ms inference, 4.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.2ms
# Speed: 1.9ms preprocess, 10.2ms inference, 6.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.1ms
# Speed: 1.9ms preprocess, 13.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 2.0ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.7ms
# Speed: 2.0ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 2.2ms preprocess, 12.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 2.3ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 3.1ms preprocess, 13.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.7ms
# Speed: 2.3ms preprocess, 22.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.0ms
# Speed: 1.8ms preprocess, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.6ms
# Speed: 2.2ms preprocess, 10.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.5ms
# Speed: 2.8ms preprocess, 15.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.2ms
# Speed: 2.0ms preprocess, 13.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.2ms
# Speed: 1.9ms preprocess, 15.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.4ms
# Speed: 2.1ms preprocess, 15.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 25.6ms
# Speed: 3.0ms preprocess, 25.6ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.0ms
# Speed: 2.8ms preprocess, 24.0ms inference, 11.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.4ms
# Speed: 2.9ms preprocess, 27.4ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 28.3ms
# Speed: 2.8ms preprocess, 28.3ms inference, 5.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.9ms
# Speed: 2.4ms preprocess, 15.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.2ms
# Speed: 2.2ms preprocess, 20.2ms inference, 12.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 1.9ms preprocess, 13.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 38.2ms
# Speed: 3.5ms preprocess, 38.2ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 32.2ms
# Speed: 5.7ms preprocess, 32.2ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.3ms
# Speed: 3.4ms preprocess, 27.3ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.6ms
# Speed: 3.1ms preprocess, 17.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.2ms
# Speed: 2.4ms preprocess, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.4ms
# Speed: 2.0ms preprocess, 12.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.4ms
# Speed: 2.7ms preprocess, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.7ms
# Speed: 2.1ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.6ms
# Speed: 1.9ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.7ms
# Speed: 1.9ms preprocess, 21.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.4ms
# Speed: 2.2ms preprocess, 16.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.7ms
# Speed: 2.8ms preprocess, 14.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.2ms
# Speed: 2.1ms preprocess, 19.2ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 25.5ms
# Speed: 2.7ms preprocess, 25.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 26.1ms
# Speed: 2.1ms preprocess, 26.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 2.4ms preprocess, 12.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.0ms
# Speed: 2.9ms preprocess, 20.0ms inference, 7.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.2ms
# Speed: 2.0ms preprocess, 22.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.8ms
# Speed: 1.9ms preprocess, 11.8ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.9ms
# Speed: 2.6ms preprocess, 17.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.9ms
# Speed: 3.7ms preprocess, 27.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.9ms
# Speed: 2.9ms preprocess, 18.9ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.8ms
# Speed: 2.9ms preprocess, 18.8ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 2.6ms preprocess, 14.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.5ms
# Speed: 1.9ms preprocess, 16.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.2ms
# Speed: 2.5ms preprocess, 24.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.5ms
# Speed: 2.2ms preprocess, 15.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 28.8ms
# Speed: 5.1ms preprocess, 28.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.8ms
# Speed: 3.0ms preprocess, 19.8ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 25.7ms
# Speed: 3.8ms preprocess, 25.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.7ms
# Speed: 2.3ms preprocess, 18.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.6ms
# Speed: 2.7ms preprocess, 15.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.6ms
# Speed: 2.9ms preprocess, 23.6ms inference, 4.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.5ms
# Speed: 2.4ms preprocess, 14.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.2ms
# Speed: 3.8ms preprocess, 17.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 2.0ms preprocess, 12.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 3.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 28.9ms
# Speed: 2.1ms preprocess, 28.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.6ms
# Speed: 2.1ms preprocess, 12.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.4ms
# Speed: 1.9ms preprocess, 15.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.3ms
# Speed: 2.1ms preprocess, 15.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
# YOLOv11 Pose Estimator FPS: 15.10

# %%
import torch
import time
import cv2
import numpy as np
from ultralytics import YOLO

# Load model (adjust path if needed)
model = YOLO("yolo11s-pose.pt").cuda()
model.eval()

# Load dummy image (or use webcam frame)
img = np.random.randint(0, 255, (640, 640, 3), dtype=np.uint8)
img_tensor = torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0).float() / 255.0  # Shape: [1, 3, 640, 640]

model_action = getActionNet('./configs/action/MB_ft_NTU60_xsub_lite_temp_comp.yaml').cuda()
model_action.eval()

input_tensor = torch.randn(1, 2, 243, 17, 3).cuda()
# Warm-up
with torch.no_grad():
    for _ in range(10):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)

# Measure FPS
num_iters = 100
torch.cuda.synchronize()
start_time = time.time()

with torch.no_grad():
    for _ in range(num_iters):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)
        torch.cuda.synchronize()

end_time = time.time()
elapsed = end_time - start_time
fps = num_iters / elapsed

print(f"YOLOv11 Pose Estimator FPS: {fps:.2f}")
# Out:
# True
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 2.9ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 2.5ms preprocess, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.7ms
# Speed: 4.6ms preprocess, 17.7ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.1ms
# Speed: 2.4ms preprocess, 14.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.6ms
# Speed: 2.2ms preprocess, 17.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 34.3ms
# Speed: 3.0ms preprocess, 34.3ms inference, 7.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.5ms
# Speed: 2.8ms preprocess, 23.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.3ms
# Speed: 2.5ms preprocess, 18.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 28.4ms
# Speed: 3.2ms preprocess, 28.4ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 5.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.9ms
# Speed: 2.0ms preprocess, 16.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.8ms
# Speed: 2.3ms preprocess, 18.8ms inference, 6.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.9ms
# Speed: 3.4ms preprocess, 15.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 1.7ms preprocess, 12.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.8ms
# Speed: 2.2ms preprocess, 15.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 29.1ms
# Speed: 2.3ms preprocess, 29.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.3ms
# Speed: 3.7ms preprocess, 14.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.4ms
# Speed: 1.9ms preprocess, 14.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.8ms
# Speed: 2.0ms preprocess, 13.8ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.0ms
# Speed: 1.9ms preprocess, 16.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.6ms
# Speed: 1.6ms preprocess, 19.6ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.8ms
# Speed: 1.9ms preprocess, 17.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.9ms
# Speed: 1.7ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.0ms
# Speed: 2.8ms preprocess, 15.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.0ms
# Speed: 1.7ms preprocess, 12.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 2.3ms preprocess, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.7ms
# Speed: 1.7ms preprocess, 16.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.4ms
# Speed: 2.6ms preprocess, 16.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.0ms
# Speed: 1.6ms preprocess, 11.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.8ms
# Speed: 1.8ms preprocess, 11.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.8ms
# Speed: 1.7ms preprocess, 21.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.3ms
# Speed: 1.7ms preprocess, 19.3ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.0ms
# Speed: 2.0ms preprocess, 20.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.2ms
# Speed: 1.6ms preprocess, 11.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.9ms
# Speed: 1.6ms preprocess, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.2ms
# Speed: 1.8ms preprocess, 16.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 1.9ms preprocess, 12.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.0ms
# Speed: 2.1ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.6ms
# Speed: 2.2ms preprocess, 16.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 34.3ms
# Speed: 2.8ms preprocess, 34.3ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.2ms
# Speed: 2.9ms preprocess, 23.2ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.1ms
# Speed: 3.4ms preprocess, 23.1ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 28.0ms
# Speed: 2.6ms preprocess, 28.0ms inference, 6.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 1.8ms preprocess, 12.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.3ms
# Speed: 2.0ms preprocess, 14.3ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 26.7ms
# Speed: 3.0ms preprocess, 26.7ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.2ms
# Speed: 3.0ms preprocess, 17.2ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.7ms
# Speed: 2.1ms preprocess, 17.7ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.9ms
# Speed: 2.9ms preprocess, 16.9ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.3ms
# Speed: 3.5ms preprocess, 14.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.1ms
# Speed: 2.2ms preprocess, 24.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.7ms
# Speed: 2.1ms preprocess, 14.7ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.9ms
# Speed: 1.8ms preprocess, 13.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.6ms
# Speed: 2.2ms preprocess, 13.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.0ms
# Speed: 1.6ms preprocess, 12.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.1ms
# Speed: 1.8ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.7ms
# Speed: 1.6ms preprocess, 11.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 1.9ms preprocess, 12.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.6ms
# Speed: 2.0ms preprocess, 18.6ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.2ms
# Speed: 1.8ms preprocess, 12.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.6ms
# Speed: 1.7ms preprocess, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.0ms
# Speed: 1.9ms preprocess, 20.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.8ms
# Speed: 1.7ms preprocess, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.2ms
# Speed: 1.7ms preprocess, 15.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 2.7ms preprocess, 12.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.9ms
# Speed: 1.7ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 25.4ms
# Speed: 2.0ms preprocess, 25.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.3ms
# Speed: 1.9ms preprocess, 19.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.5ms
# Speed: 2.3ms preprocess, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.8ms
# Speed: 2.6ms preprocess, 20.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.6ms
# Speed: 1.6ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.3ms
# Speed: 1.8ms preprocess, 13.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.5ms
# Speed: 2.0ms preprocess, 14.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 30.1ms
# Speed: 3.3ms preprocess, 30.1ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 28.3ms
# Speed: 2.6ms preprocess, 28.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.7ms
# Speed: 1.8ms preprocess, 20.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 36.4ms
# Speed: 2.8ms preprocess, 36.4ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.8ms
# Speed: 2.2ms preprocess, 13.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.7ms
# Speed: 1.8ms preprocess, 18.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.4ms
# Speed: 1.8ms preprocess, 11.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.3ms
# Speed: 1.9ms preprocess, 24.3ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 1.7ms preprocess, 12.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.2ms
# Speed: 3.0ms preprocess, 14.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.2ms
# Speed: 1.9ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.0ms
# Speed: 1.7ms preprocess, 16.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.8ms
# Speed: 1.8ms preprocess, 10.8ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.3ms
# Speed: 2.0ms preprocess, 15.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 2.7ms preprocess, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 2.1ms preprocess, 12.9ms inference, 9.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 1.8ms preprocess, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 4.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.5ms
# Speed: 2.9ms preprocess, 19.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.3ms
# Speed: 2.9ms preprocess, 22.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 2.0ms preprocess, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.4ms
# Speed: 2.4ms preprocess, 16.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.1ms
# Speed: 1.9ms preprocess, 15.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 1.7ms preprocess, 13.5ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
# YOLOv11 Pose Estimator FPS: 16.21

# %%
import torch
import time
import cv2
import numpy as np
from ultralytics import YOLO

# Load model (adjust path if needed)
model = YOLO("yolo11n-pose.pt").cuda()
model.eval()

# Load dummy image (or use webcam frame)
img = np.random.randint(0, 255, (640, 640, 3), dtype=np.uint8)
img_tensor = torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0).float() / 255.0  # Shape: [1, 3, 640, 640]

model_action = getActionNet('./configs/action/MB_ft_NTU60_xsub_lite_temp_comp.yaml').cuda()
model_action.eval()

input_tensor = torch.randn(1, 2, 243, 17, 3).cuda()
# Warm-up
with torch.no_grad():
    for _ in range(10):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)

# Measure FPS
num_iters = 100
torch.cuda.synchronize()
start_time = time.time()

with torch.no_grad():
    for _ in range(num_iters):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)
        torch.cuda.synchronize()

end_time = time.time()
elapsed = end_time - start_time
fps = num_iters / elapsed

print(f"YOLOv11 Pose Estimator FPS: {fps:.2f}")
# Out:
# True
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.6ms
# Speed: 2.0ms preprocess, 13.6ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.4ms
# Speed: 2.5ms preprocess, 13.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.2ms
# Speed: 1.8ms preprocess, 16.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.3ms
# Speed: 2.9ms preprocess, 23.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.6ms
# Speed: 1.8ms preprocess, 12.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.0ms
# Speed: 2.7ms preprocess, 15.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 1.8ms preprocess, 13.0ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.9ms
# Speed: 2.4ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.8ms
# Speed: 1.8ms preprocess, 19.8ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.5ms
# Speed: 2.7ms preprocess, 14.5ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.8ms
# Speed: 1.7ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.6ms
# Speed: 2.3ms preprocess, 21.6ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.6ms
# Speed: 7.5ms preprocess, 27.6ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.4ms
# Speed: 3.9ms preprocess, 16.4ms inference, 3.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.4ms
# Speed: 10.2ms preprocess, 20.4ms inference, 5.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.9ms
# Speed: 2.2ms preprocess, 19.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.8ms
# Speed: 2.0ms preprocess, 15.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.1ms
# Speed: 2.1ms preprocess, 16.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.7ms
# Speed: 3.0ms preprocess, 23.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.1ms
# Speed: 3.2ms preprocess, 17.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.7ms
# Speed: 3.1ms preprocess, 20.7ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.3ms
# Speed: 2.1ms preprocess, 24.3ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.7ms
# Speed: 2.3ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.5ms
# Speed: 1.8ms preprocess, 18.5ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.7ms
# Speed: 2.2ms preprocess, 14.7ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.7ms
# Speed: 2.0ms preprocess, 13.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.9ms
# Speed: 2.8ms preprocess, 15.9ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.0ms
# Speed: 2.7ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.0ms
# Speed: 2.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.9ms
# Speed: 1.8ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.6ms
# Speed: 3.8ms preprocess, 21.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.9ms
# Speed: 2.0ms preprocess, 14.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.3ms
# Speed: 2.2ms preprocess, 18.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.5ms
# Speed: 2.4ms preprocess, 21.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.0ms
# Speed: 2.1ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.8ms
# Speed: 2.6ms preprocess, 16.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.1ms
# Speed: 2.0ms preprocess, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.4ms
# Speed: 2.3ms preprocess, 19.4ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.7ms
# Speed: 1.8ms preprocess, 11.7ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.6ms
# Speed: 1.7ms preprocess, 13.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.9ms
# Speed: 2.9ms preprocess, 22.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.7ms
# Speed: 2.2ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.2ms
# Speed: 2.4ms preprocess, 19.2ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.8ms
# Speed: 2.9ms preprocess, 16.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.9ms
# Speed: 2.7ms preprocess, 16.9ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.6ms
# Speed: 3.0ms preprocess, 24.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 1.9ms preprocess, 12.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.1ms
# Speed: 2.2ms preprocess, 14.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 2.4ms preprocess, 13.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.8ms
# Speed: 10.3ms preprocess, 17.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 1.7ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.7ms
# Speed: 1.7ms preprocess, 11.7ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.0ms
# Speed: 2.5ms preprocess, 17.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.8ms
# Speed: 2.0ms preprocess, 16.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 1.7ms preprocess, 12.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.1ms
# Speed: 1.7ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 25.9ms
# Speed: 1.8ms preprocess, 25.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.2ms
# Speed: 1.7ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 1.8ms preprocess, 12.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 1.9ms preprocess, 12.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 1.7ms preprocess, 12.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 33.4ms
# Speed: 2.0ms preprocess, 33.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.9ms
# Speed: 1.8ms preprocess, 12.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.6ms
# Speed: 1.8ms preprocess, 22.6ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.3ms
# Speed: 1.8ms preprocess, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.4ms
# Speed: 1.7ms preprocess, 12.4ms inference, 5.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.3ms
# Speed: 3.2ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 2.5ms preprocess, 12.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.8ms
# Speed: 2.0ms preprocess, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.3ms
# Speed: 1.7ms preprocess, 14.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.4ms
# Speed: 3.3ms preprocess, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.1ms
# Speed: 2.0ms preprocess, 14.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.7ms
# Speed: 1.9ms preprocess, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.0ms
# Speed: 2.8ms preprocess, 24.0ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.8ms
# Speed: 2.5ms preprocess, 20.8ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.2ms
# Speed: 2.1ms preprocess, 16.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.0ms
# Speed: 2.2ms preprocess, 15.0ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 31.0ms
# Speed: 2.1ms preprocess, 31.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.3ms
# Speed: 1.8ms preprocess, 11.3ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 1.8ms preprocess, 12.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.5ms
# Speed: 1.9ms preprocess, 11.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.4ms
# Speed: 1.7ms preprocess, 11.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.4ms
# Speed: 1.7ms preprocess, 14.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 2.6ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.1ms
# Speed: 2.1ms preprocess, 17.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.8ms
# Speed: 2.9ms preprocess, 19.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.0ms
# Speed: 3.2ms preprocess, 22.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.5ms
# Speed: 2.9ms preprocess, 27.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.8ms
# Speed: 3.5ms preprocess, 17.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.7ms
# Speed: 1.8ms preprocess, 13.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.3ms
# Speed: 2.1ms preprocess, 11.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.0ms
# Speed: 2.4ms preprocess, 15.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.1ms
# Speed: 1.8ms preprocess, 21.1ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.4ms
# Speed: 2.3ms preprocess, 12.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.1ms
# Speed: 2.1ms preprocess, 18.1ms inference, 4.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.8ms
# Speed: 1.7ms preprocess, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.7ms
# Speed: 2.3ms preprocess, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.3ms
# Speed: 1.7ms preprocess, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
# YOLOv11 Pose Estimator FPS: 15.15

# %%
import torch
import time
import cv2
import numpy as np
from ultralytics import YOLO

# Load model (adjust path if needed)
model = YOLO("yolo11m-pose.pt").cuda()
model.eval()

# Load dummy image (or use webcam frame)
img = np.random.randint(0, 255, (640, 640, 3), dtype=np.uint8)
img_tensor = torch.from_numpy(img).permute(2, 0, 1).unsqueeze(0).float() / 255.0  # Shape: [1, 3, 640, 640]

model_action = getActionNet('./configs/action/MB_ft_NTU60_xsub_lite_temp_comp.yaml').cuda()
model_action.eval()

input_tensor = torch.randn(1, 2, 243, 17, 3).cuda()
# Warm-up
with torch.no_grad():
    for _ in range(10):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)

# Measure FPS
num_iters = 100
torch.cuda.synchronize()
start_time = time.time()

with torch.no_grad():
    for _ in range(num_iters):
        _ = model('bus.jpg')
        _ = model_action(input_tensor)
        torch.cuda.synchronize()

end_time = time.time()
elapsed = end_time - start_time
fps = num_iters / elapsed

print(f"YOLOv11 Pose Estimator FPS: {fps:.2f}")
# Out:
# True
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 39.4ms
# Speed: 2.7ms preprocess, 39.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.2ms
# Speed: 3.1ms preprocess, 17.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.3ms
# Speed: 2.5ms preprocess, 19.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.7ms
# Speed: 2.4ms preprocess, 15.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.7ms
# Speed: 1.9ms preprocess, 16.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.2ms
# Speed: 2.0ms preprocess, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.5ms
# Speed: 2.9ms preprocess, 22.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.4ms
# Speed: 3.1ms preprocess, 21.4ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.2ms
# Speed: 1.9ms preprocess, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.7ms
# Speed: 1.8ms preprocess, 13.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.4ms
# Speed: 1.6ms preprocess, 14.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.1ms
# Speed: 1.7ms preprocess, 15.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.6ms
# Speed: 1.7ms preprocess, 13.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.3ms
# Speed: 2.2ms preprocess, 13.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.5ms
# Speed: 4.8ms preprocess, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.9ms
# Speed: 1.7ms preprocess, 20.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.6ms
# Speed: 1.9ms preprocess, 20.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.8ms
# Speed: 1.6ms preprocess, 14.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.8ms
# Speed: 1.8ms preprocess, 13.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.0ms
# Speed: 1.6ms preprocess, 13.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 1.6ms preprocess, 13.5ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.7ms
# Speed: 2.7ms preprocess, 22.7ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 1.6ms preprocess, 14.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.5ms
# Speed: 1.7ms preprocess, 15.5ms inference, 6.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.1ms
# Speed: 1.7ms preprocess, 18.1ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.8ms
# Speed: 1.7ms preprocess, 21.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.9ms
# Speed: 1.7ms preprocess, 27.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.9ms
# Speed: 3.1ms preprocess, 17.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.6ms
# Speed: 10.0ms preprocess, 18.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 37.5ms
# Speed: 2.8ms preprocess, 37.5ms inference, 11.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.4ms
# Speed: 2.1ms preprocess, 20.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.6ms
# Speed: 1.9ms preprocess, 15.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.7ms
# Speed: 2.1ms preprocess, 18.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.2ms
# Speed: 1.9ms preprocess, 18.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.6ms
# Speed: 5.4ms preprocess, 23.6ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.6ms
# Speed: 2.8ms preprocess, 24.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 26.6ms
# Speed: 3.7ms preprocess, 26.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.6ms
# Speed: 2.8ms preprocess, 18.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 54.8ms
# Speed: 10.8ms preprocess, 54.8ms inference, 10.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 29.4ms
# Speed: 2.6ms preprocess, 29.4ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 30.0ms
# Speed: 3.4ms preprocess, 30.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 1.7ms preprocess, 13.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.0ms
# Speed: 4.7ms preprocess, 18.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.5ms
# Speed: 1.7ms preprocess, 12.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.5ms
# Speed: 1.7ms preprocess, 13.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.9ms
# Speed: 3.9ms preprocess, 18.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.9ms
# Speed: 1.8ms preprocess, 13.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.2ms
# Speed: 4.1ms preprocess, 23.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.3ms
# Speed: 2.1ms preprocess, 18.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 26.6ms
# Speed: 3.1ms preprocess, 26.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.5ms
# Speed: 1.7ms preprocess, 14.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.1ms
# Speed: 1.7ms preprocess, 14.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.4ms
# Speed: 3.8ms preprocess, 24.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 24.9ms
# Speed: 2.5ms preprocess, 24.9ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.7ms
# Speed: 1.7ms preprocess, 14.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 32.4ms
# Speed: 2.7ms preprocess, 32.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.6ms
# Speed: 1.7ms preprocess, 15.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.4ms
# Speed: 1.8ms preprocess, 21.4ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.9ms
# Speed: 1.7ms preprocess, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.6ms
# Speed: 2.4ms preprocess, 16.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.4ms
# Speed: 3.2ms preprocess, 27.4ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 22.2ms
# Speed: 2.5ms preprocess, 22.2ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 34.1ms
# Speed: 2.8ms preprocess, 34.1ms inference, 3.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.3ms
# Speed: 1.9ms preprocess, 16.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.6ms
# Speed: 2.9ms preprocess, 20.6ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 30.2ms
# Speed: 1.8ms preprocess, 30.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.4ms
# Speed: 2.0ms preprocess, 13.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 29.9ms
# Speed: 6.0ms preprocess, 29.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.0ms
# Speed: 3.9ms preprocess, 19.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.0ms
# Speed: 1.9ms preprocess, 15.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.9ms
# Speed: 3.7ms preprocess, 15.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.5ms
# Speed: 1.9ms preprocess, 14.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 27.8ms
# Speed: 2.6ms preprocess, 27.8ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.7ms
# Speed: 3.3ms preprocess, 23.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.4ms
# Speed: 1.8ms preprocess, 21.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.7ms
# Speed: 1.8ms preprocess, 15.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.5ms
# Speed: 1.8ms preprocess, 15.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 26.6ms
# Speed: 1.7ms preprocess, 26.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 18.3ms
# Speed: 2.0ms preprocess, 18.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 33.9ms
# Speed: 2.9ms preprocess, 33.9ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.9ms
# Speed: 3.4ms preprocess, 16.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 19.6ms
# Speed: 2.0ms preprocess, 19.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 20.1ms
# Speed: 2.4ms preprocess, 20.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.3ms
# Speed: 1.8ms preprocess, 15.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.8ms
# Speed: 2.9ms preprocess, 17.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.9ms
# Speed: 1.8ms preprocess, 13.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.5ms
# Speed: 2.0ms preprocess, 15.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.0ms
# Speed: 2.2ms preprocess, 16.0ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 1.8ms preprocess, 12.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.5ms
# Speed: 2.3ms preprocess, 16.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.3ms
# Speed: 2.0ms preprocess, 17.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 21.0ms
# Speed: 1.9ms preprocess, 21.0ms inference, 5.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 13.2ms
# Speed: 1.7ms preprocess, 13.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 1.7ms preprocess, 14.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 17.2ms
# Speed: 2.3ms preprocess, 17.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 23.8ms
# Speed: 3.2ms preprocess, 23.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 50.3ms
# Speed: 3.0ms preprocess, 50.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 28.3ms
# Speed: 1.8ms preprocess, 28.3ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 16.7ms
# Speed: 2.9ms preprocess, 16.7ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 26.5ms
# Speed: 2.1ms preprocess, 26.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 31.0ms
# Speed: 3.5ms preprocess, 31.0ms inference, 6.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.8ms
# Speed: 1.6ms preprocess, 12.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 12.6ms
# Speed: 1.7ms preprocess, 12.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 14.0ms
# Speed: 2.1ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.5ms
# Speed: 2.9ms preprocess, 15.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 15.6ms
# Speed: 2.0ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /home/jovianto/MotionBERT/bus.jpg: 640x480 4 persons, 41.7ms
# Speed: 2.4ms preprocess, 41.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
# YOLOv11 Pose Estimator FPS: 14.70
